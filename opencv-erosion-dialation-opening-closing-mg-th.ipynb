# %% [markdown]
# OpenCv Erosion, Dialation, Opening-Closing, MG

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as img
import cv2
import numpy as np
from scipy import ndimage

# %%
image = cv2.imread('/kaggle/input/image-pro/Example.png')
erosion = cv2.erode(image,kernel,iterations = 1)
plt.imshow(erosion)

# %%
image = cv2.imread('/kaggle/input/image-pro/Example.png')
dialation = cv2.dilate(image,kernel,iterations = 1)
plt.imshow(dialation)

# %%
image = cv2.imread('/kaggle/input/image-pro/Example.png')
opening = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
plt.imshow(opening)

# %%
image = cv2.imread('/kaggle/input/image-pro/Example.png')
closing = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)
plt.imshow(closing)

# %%
image = cv2.imread('../input/image-pro/man.png',cv2.COLOR_BGR2GRAY)
tophat = cv2.morphologyEx(image, cv2.MORPH_TOPHAT, kernel)
plt.imshow(tophat)

# %%
image = cv2.imread('../input/image-pro/man.png',cv2.COLOR_BGR2GRAY)
blackhat = cv2.morphologyEx(image, cv2.MORPH_BLACKHAT, kernel)
plt.imshow(blackhat)

# %%
image = cv2.imread('../input/image-pro/man.png')
gradient = cv2.morphologyEx(image, cv2.MORPH_GRADIENT, kernel)
plt.imshow(gradient)

# %% [markdown]
# Threshold

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
img = img.imread('../input/image-pro/Book.jpg')
plt.imshow(img)

# %%
retval, threshold = cv2.threshold(img, 12, 255, cv2.THRESH_BINARY)
plt.imshow(threshold)

# %%
grayscaled = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
retval, threshold = cv2.threshold(grayscaled, 10, 255, cv2.THRESH_BINARY)
plt.imshow(threshold)

# %%
th = cv2.adaptiveThreshold(grayscaled, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 115, 1)
plt.imshow(th)

# %%
retval2,threshold2 = cv2.threshold(grayscaled,125,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.imshow(threshold2)

# %% [markdown]
# Calculating

# %%
inputs = [1.0, 2.0, 3.0, 2.5]

weights1 = [0.2, 0.8, -0.5, 1.0]
weights2 = [0.5, -0.91, 0.26, -0.5]
weights3 = [-0.26, -0.27, 0.17, 0.87]

bias1 = 2.0
bias2 = 3.0
bias3 = 0.5

output = [inputs[0]*weights1[0] + inputs[1]*weights1[1] + inputs[2]*weights1[2] + inputs[3]*weights1[3] + bias1,
          inputs[0]*weights2[0] + inputs[1]*weights2[1] + inputs[2]*weights2[2] + inputs[3]*weights2[3] + bias2,
          inputs[0]*weights3[0] + inputs[1]*weights3[1] + inputs[2]*weights3[2] + inputs[3]*weights3[3] + bias3]
print(output)
# Out:
# [4.8, 1.21, 2.385]
